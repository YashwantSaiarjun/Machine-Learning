# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
data = pd.read_csv("C:/Users/admin/Documents/ML DL course/simplilearn mL/decision tree/Decision_Tree_ Dataset.csv",sep=",",header=0)

# %%
data.head()
# Out:
#      1      2    3     4    sum Unnamed: 5
# 0  201  10018  250  3046  13515        yes
# 1  205  10016  395  3044  13660        yes
# 2  257  10129  109  3251  13746        yes
# 3  246  10064  324  3137  13771        yes
# 4  117  10115  496  3094  13822        yes

# %%
for col in data.columns:
    print(col)
# Out:
# 1
# 2
# 3
# 4
# sum
# Unnamed: 5

# %%
data.rename(columns={'1':'Initial Payment','2':'Last Payment','3':'Credit Score','4':'House Number','sum':'Sum','Unnamed: 5':'Result'})
# Out:
#      Initial Payment  Last Payment  Credit Score  House Number    Sum Result
# 0                201         10018           250          3046  13515    yes
# 1                205         10016           395          3044  13660    yes
# 2                257         10129           109          3251  13746    yes
# 3                246         10064           324          3137  13771    yes
# 4                117         10115           496          3094  13822    yes
# ..               ...           ...           ...           ...    ...    ...
# 995              413         14914           523          4683  20533     No
# 996              359         14423           927          4838  20547     No
# 997              316         14872           613          4760  20561     No
# 998              305         14926           897          4572  20700     No
# 999              168         14798           834          4937  20737     No
#
# [1000 rows x 6 columns]

# %%
data.shape
# Out:
# (1000, 6)

# %%
x=data.values[:,0:5]
x
# Out:
# array([[201, 10018, 250, 3046, 13515],
#        [205, 10016, 395, 3044, 13660],
#        [257, 10129, 109, 3251, 13746],
#        ...,
#        [316, 14872, 613, 4760, 20561],
#        [305, 14926, 897, 4572, 20700],
#        [168, 14798, 834, 4937, 20737]], dtype=object)

# %%
y= data.values[:,5]
y
# Out:
# array(['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=100)

# %%
model= DecisionTreeClassifier(criterion="entropy",random_state=100,max_depth=3,min_samples_leaf=5)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
pred = model.predict(x_test)
pred
# Out:
# array(['yes', 'yes', 'No', 'yes', 'No', 'yes', 'No', 'No', 'No', 'No',
#        'No', 'No', 'yes', 'No', 'No', 'yes', 'yes', 'No', 'yes', 'No',
#        'No', 'yes', 'No', 'yes', 'yes', 'No', 'No', 'yes', 'No', 'No',
#        'No', 'yes', 'yes', 'yes', 'yes', 'No', 'No', 'No', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'No', 'No', 'yes', 'No', 'yes', 'No', 'No',
#        'yes', 'No', 'yes', 'yes', 'yes', 'yes', 'No', 'No', 'No', 'yes',
#        'yes', 'No', 'No', 'yes', 'No', 'yes', 'yes', 'yes', 'No', 'yes',
#        'No', 'No', 'No', 'yes', 'No', 'yes', 'yes', 'No', 'yes', 'No',
#        'No', 'No', 'No', 'yes', 'No', 'yes', 'No', 'No', 'yes', 'No',
#        'yes', 'yes', 'No', 'yes', 'yes', 'No', 'yes', 'yes', 'yes', 'yes',
#        'No', 'No', 'yes', 'No', 'No', 'yes', 'yes', 'yes', 'No', 'yes',
#        'yes', 'yes', 'yes', 'No', 'No', 'yes', 'yes', 'yes', 'No', 'yes',
#        'No', 'No', 'yes', 'yes', 'No', 'No', 'yes', 'yes', 'No', 'No',
# ...

# %%
print("Accuracy Score : ",accuracy_score(y_test,pred)*100)
# Out:
# Accuracy Score :  100.0
